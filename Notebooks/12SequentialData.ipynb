# %% [markdown]
# # Time Series and Frequent Sequences

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
# %matplotlib notebook

# %%
datapath = '../Data/'

data = np.loadtxt(datapath+'tseries.csv')
fig = plt.figure(figsize=(12,6))
plt.plot(data);

# %%
import amltlearn.time_series.discretization.SAX as SAX
saxtrans = SAX(window_length=data.shape[0], step=10, word_length=500, voc_size=11)
datatrans = saxtrans.transform(data)
fig = plt.figure(figsize=(12,6))
plt.plot(datatrans[0]);
